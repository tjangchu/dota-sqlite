# %%
import pandas as pd

# %%
#!pip install ipython-sql
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:////Users/milot/iCloudDrive/Documents/codes/dota-sqlite/data/dota.db

# %%
# show all tables
# %sql select name, type from sqlite_master
# Out:
#  * sqlite:////Users/milot/iCloudDrive/Documents/codes/dota-sqlite/data/dota.db
# Done.
# [('hero_ref', 'table'),
#  ('match', 'table'),
#  ('pick_ban', 'table'),
#  ('player', 'table'),
#  ('picks', 'view'),
#  ('bans', 'view')]

# %%
# show DDL
# %sql select name, sql from sqlite_master where name = 'hero_ref'
# Out:
#  * sqlite:////Users/milot/iCloudDrive/Documents/codes/dota-sqlite/data/dota.db
# Done.
# [('hero_ref', 'CREATE TABLE "hero_ref" (\n"id" TEXT,\n  "name" TEXT,\n  "localized_name" TEXT,\n  "primary_attr" TEXT,\n  "attack_type" TEXT,\n  "roles" TEXT,\n  "legs" TEXT\n)')]

# %%
# %sql select * from picks
# Out:
#  * sqlite:////Users/milot/iCloudDrive/Documents/codes/dota-sqlite/data/dota.db
# Done.
# [('AS Monaco Gambit', 'Tusk', 4),
#  ('AS Monaco Gambit', 'Lion', 4),
#  ('AS Monaco Gambit', 'Enigma', 4),
#  ('AS Monaco Gambit', 'Abaddon', 4),
#  ('AS Monaco Gambit', 'Viper', 3),
#  ('AS Monaco Gambit', 'Wraith King', 2),
#  ('AS Monaco Gambit', 'Underlord', 2),
#  ('AS Monaco Gambit', 'Timbersaw', 2),
#  ('AS Monaco Gambit', 'Spirit Breaker', 2),
#  ('AS Monaco Gambit', 'Puck', 2),
#  ('AS Monaco Gambit', 'Monkey King', 2),
#  ('AS Monaco Gambit', 'Io', 2),
#  ('AS Monaco Gambit', 'Beastmaster', 2),
#  ('AS Monaco Gambit', 'Weaver', 1),
#  ('AS Monaco Gambit', 'Tidehunter', 1),
#  ('AS Monaco Gambit', 'Terrorblade', 1),
#  ('AS Monaco Gambit', 'Shadow Fiend', 1),
#  ('AS Monaco Gambit', 'Phoenix', 1),
#  ('AS Monaco Gambit', 'Phantom Assassin', 1),
#  ('AS Monaco Gambit', 'Outworld Destroyer', 1),
#  ('AS Monaco Gambit', 'Nyx Assassin', 1),
#  ('AS Monaco Gambit', "Nature's Prophet", 1),
# ...
